# %%
import pandas as pd
import numpy as np

url    = 'https://home.sis.siam.edu/registrar/student_inclass_all.asp?backto=teach_time&option=1&classid=203395&courseid=15336&acadyear=2563&semester=3&normalURL=f%5Fcmd%3D2%26officercode%3D20710%26officerid%3D20710%26officername%3D%25BC%25C8%252E%25B4%25C3%252E%2B%25B7%25D1%25C8%25B9%25D1%25C2%2B%25BE%25C5%25CD%25C2%25CA%25D8%25C7%25C3%25C3%25B3%26acadyear%3D2563%26rnd%3D44352%2E4941435185%26firstday%3D31%2F5%2F2564%26semester%3D3&avs296126231=5'
List = pd.read_html(url)

df = List[3]
df =  df.loc[3:,0:2].reset_index( drop = True).drop(0,axis=1)
df0= df.rename(columns={1:'id',2:'Name'})
df0['id']= df0['id'].astype('string')

# %%
df       = df0.copy()
df['R1'] = df0['id'].apply(lambda x: np.random.randint(500) )
df['R2'] = df0['id'].apply(lambda x: np.random.randint(500) )
df['R3'] = df0['id'].apply(lambda x: np.random.randint(500) )
df['R4'] = df0['id'].apply(lambda x: np.random.randint(500) )
df['R5'] = df0['id'].apply(lambda x: np.random.randint(500) )
df['R6'] = df0['id'].apply(lambda x: np.random.randint(500) )
df['choose'] = df0['id'].apply(lambda x: '1.'+str(1+int(x[-1])%2) )

df
# Out:
#             id                    Name   R1   R2   R3   R4   R5   R6 choose
# 0   6223200004   นายธนศักดิ์ จันทรัตน์  421   15  116  196   74  141    1.1
# 1   6223200006   นายภัทรพล ศรีเทียนทอง  303  384  295  415   85  203    1.1
# 2   6223200010    นายณัฐพงศ์ นาคทรัพย์  344  499  485   57  114  234    1.1
# 3   6223200011     นายรตนากร อักษรวรรณ  308  273  103  427  321  428    1.2
# 4   6223200012    นายณัฐวุฒิ แก้วประไพ  415  258  114   10  403  472    1.1
# 5   6223200014     นายนิวัฒน์ รัตนสาคร  112  160   73  436  117  161    1.1
# 6   6223200019    นายชาคริต เอี่ยมสกุล  122  392  104   36  201  157    1.2
# 7   6223200021    นายนนธวัช เจริญฤทธิ์  463  121   40  176  371   14    1.2
# 8   6223200022          นายคมสัน อำนวย  327  465   75  322   66  411    1.1
# 9   6223200025         นายจรัญ รักญาติ  349  148  178  195  368   11    1.2
# 10  6223200026     นายฐิติกานต์ อิ่มใจ  449  228   88  126  239  178    1.1
# 11  6223200027  นายพรพิพัฒน์ กรรฐโรจน์  238  125  271  245  360  368    1.2
# 12  6223200030   นายภูรินทร์ กิติจนาทร  310   69  112  142  481  153    1.1
# 13  6223200031     นายกรวุฒิ อิ่มอาดูร  400   65  302  150  408  157    1.2
# 14  6223200032  นายพงษ์เพชร พุ่มลอยฟ้า   24  178   97  376  207  383    1.1
# 15  6223200033       นางสาวรณิดา นพวัง   99   40  119  221  420  312    1.2
# 16  6223220002      นายอรรถพล เนตรวงค์  224  252  200  104  490  242    1.1
# 17  6224220001       นางสาวปวีณา บุญนำ  307  466  214  303   61   31    1.2

# %% [markdown]
# # ช้อ 1.1 . จงหาค่า $ I_1, I_2, I_3 $ โดยการเขียนโปรแกรม Python
#
# ![1](https://raw.githubusercontent.com/Tuchsanai/152-333-Electrical-Engineering-Laboratory-3/master/HomeWork1/circuit_1.png)

# %% [markdown]
# # ช้อ 1.2 . จงหาค่า $ I_1, I_2, I_3 $ โดยการเขียนโปรแกรม Python
#
# ![1](https://raw.githubusercontent.com/Tuchsanai/152-333-Electrical-Engineering-Laboratory-3/master/HomeWork1/circuit_2.png)

# %% [markdown]
# # ข้อ 2 จงหารากของ

# %%
df       = df0.copy()
df['a'] = df0['id'].apply(lambda x: np.random.randint(9) )
df['b'] = df0['id'].apply(lambda x: np.random.randint(20) )
df['c'] = df0['id'].apply(lambda x: np.random.randint(70) )
df['d'] = df0['id'].apply(lambda x: np.random.randint(100) )
df['e'] = df0['id'].apply(lambda x: np.random.randint(30) )
df['f'] = df0['id'].apply(lambda x: np.random.randint(8) )


df
# Out:
#             id                    Name  a   b   c   d   e  f
# 0   6223200004   นายธนศักดิ์ จันทรัตน์  5  15  52  60  26  2
# 1   6223200006   นายภัทรพล ศรีเทียนทอง  4   6  43  31  12  1
# 2   6223200010    นายณัฐพงศ์ นาคทรัพย์  6  16  61   6   2  3
# 3   6223200011     นายรตนากร อักษรวรรณ  4  10  13  98  26  6
# 4   6223200012    นายณัฐวุฒิ แก้วประไพ  1   6   7  17  24  1
# 5   6223200014     นายนิวัฒน์ รัตนสาคร  1   7  20  29  24  5
# 6   6223200019    นายชาคริต เอี่ยมสกุล  4  11   0  32  29  2
# 7   6223200021    นายนนธวัช เจริญฤทธิ์  8  19  43  62  12  5
# 8   6223200022          นายคมสัน อำนวย  6  11   0  82  10  6
# 9   6223200025         นายจรัญ รักญาติ  3   0  14   0   3  6
# 10  6223200026     นายฐิติกานต์ อิ่มใจ  4   3   7  29  14  0
# 11  6223200027  นายพรพิพัฒน์ กรรฐโรจน์  3   1   6  84  29  1
# 12  6223200030   นายภูรินทร์ กิติจนาทร  5  14   9  50  12  0
# 13  6223200031     นายกรวุฒิ อิ่มอาดูร  6   8  56   9  29  2
# 14  6223200032  นายพงษ์เพชร พุ่มลอยฟ้า  7  14  29  73   1  1
# 15  6223200033       นางสาวรณิดา นพวัง  5   2  67  74  26  0
# 16  6223220002      นายอรรถพล เนตรวงค์  8   6  30  51  24  1
# 17  6224220001       นางสาวปวีณา บุญนำ  6  13   6  30  24  3

# %% [markdown]
# # $r(s) = (s^a  -bs^{2} +cs-d)(es^f  - 1)$
