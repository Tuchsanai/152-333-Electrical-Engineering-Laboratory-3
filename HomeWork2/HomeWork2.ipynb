# %%
import pandas as pd
import numpy as np

url    = 'https://home.sis.siam.edu/registrar/student_inclass_all.asp?backto=teach_time&option=1&classid=203395&courseid=15336&acadyear=2563&semester=3&normalURL=f%5Fcmd%3D2%26officercode%3D20710%26officerid%3D20710%26officername%3D%25BC%25C8%252E%25B4%25C3%252E%2B%25B7%25D1%25C8%25B9%25D1%25C2%2B%25BE%25C5%25CD%25C2%25CA%25D8%25C7%25C3%25C3%25B3%26acadyear%3D2563%26rnd%3D44352%2E4941435185%26firstday%3D31%2F5%2F2564%26semester%3D3&avs296126231=5'
List = pd.read_html(url)

df = List[3]
df =  df.loc[3:,0:2].reset_index( drop = True).drop(0,axis=1)
df0= df.rename(columns={1:'id',2:'Name'})
df0['id']= df0['id'].astype('string')

# %%
df       = df0.copy()
df['E1'] = df0['id'].apply(lambda x: 10*np.random.randint(800) )
df['R1'] = df0['id'].apply(lambda x: np.random.randint(500) )
df['R2'] = df0['id'].apply(lambda x: np.random.randint(500) )
df['R3'] = df0['id'].apply(lambda x: np.random.randint(500) )
df['R4'] = df0['id'].apply(lambda x: np.random.randint(500) )
df['R5'] = df0['id'].apply(lambda x: np.random.randint(500) )
df['R6'] = df0['id'].apply(lambda x: np.random.randint(500) )
df['choose'] = df0['id'].apply(lambda x: '1.'+str(1+int(x[-1])%3) )

df
# Out:
#             id                    Name    E1   R1   R2   R3   R4   R5   R6  \
# 0   6223200004   นายธนศักดิ์ จันทรัตน์  4580  133  163  341  187  154  124
# 1   6223200006   นายภัทรพล ศรีเทียนทอง  1120  221   73   46  244  392  299
# 2   6223200010    นายณัฐพงศ์ นาคทรัพย์  7160   14   40   32   87  169  119
# 3   6223200011     นายรตนากร อักษรวรรณ  2070  123  406  129  466  403  466
# 4   6223200012    นายณัฐวุฒิ แก้วประไพ  4680  231  267   57  424   31  336
# 5   6223200014     นายนิวัฒน์ รัตนสาคร  5170  268   55  313  129  400   69
# 6   6223200019    นายชาคริต เอี่ยมสกุล  1110    2   64  421  292  402   75
# 7   6223200021    นายนนธวัช เจริญฤทธิ์  1370  187  279    9  410  458  172
# 8   6223200022          นายคมสัน อำนวย  1880   96   39  254   84  200  443
# 9   6223200025         นายจรัญ รักญาติ   670  219  268   66  454  186   47
# 10  6223200026     นายฐิติกานต์ อิ่มใจ  6210  457  482  323   33  160  264
# 11  6223200027  นายพรพิพัฒน์ กรรฐโรจน์   530   15  124  488  121  426   44
# 12  6223200030   นายภูรินทร์ กิติจนาทร  2630  220  198  214  138  379  255
# 13  6223200031     นายกรวุฒิ อิ่มอาดูร  4280  297  352   88  318  375  366
# 14  6223200032  นายพงษ์เพชร พุ่มลอยฟ้า  2340  137  390  106  478  487  340
# 15  6223200033       นางสาวรณิดา นพวัง    60  420  151  176  414  431  413
# 16  6223220002      นายอรรถพล เนตรวงค์  2960  135  244  101  363  462   25
# 17  6224220001       นางสาวปวีณา บุญนำ  7770  331  498  261  141    3   54
#
#    choose
# 0     1.2
# 1     1.1
# 2     1.1
# 3     1.2
# 4     1.3
# 5     1.2
# 6     1.1
# 7     1.2
# 8     1.3
# 9     1.3
# 10    1.1
# 11    1.2
# 12    1.1
# 13    1.2
# 14    1.3
# 15    1.1
# 16    1.3
# 17    1.2

# %% [markdown]
# # ช้อ 1.1 . จงหาค่า $ I_1, I_2, I_3 $ โดยการเขียนโปรแกรม Python
#
# ![1](https://raw.githubusercontent.com/Tuchsanai/152-333-Electrical-Engineering-Laboratory-3/master/HomeWork2/data1.png)

# %% [markdown]
# # ข้อ 2 จงหารากของ

# %% [markdown]
# # $ r(s) = (s^a  -bs^{2} +cs-d)(es^f  - 1) $

# %%
df       = df0.copy()
df['a'] = df0['id'].apply(lambda x: np.random.randint(9) )
df['b'] = df0['id'].apply(lambda x: np.random.randint(20) )
df['c'] = df0['id'].apply(lambda x: np.random.randint(70) )
df['d'] = df0['id'].apply(lambda x: np.random.randint(100) )
df['e'] = df0['id'].apply(lambda x: np.random.randint(30) )
df['f'] = df0['id'].apply(lambda x: np.random.randint(8) )


df
# Out:
#             id                    Name  a   b   c   d   e  f
# 0   6223200004   นายธนศักดิ์ จันทรัตน์  5  10  53  42  14  7
# 1   6223200006   นายภัทรพล ศรีเทียนทอง  7  11  31  77  24  2
# 2   6223200010    นายณัฐพงศ์ นาคทรัพย์  2   3  23  52   3  4
# 3   6223200011     นายรตนากร อักษรวรรณ  2   2  54  74  13  6
# 4   6223200012    นายณัฐวุฒิ แก้วประไพ  8   8  39  67  29  2
# 5   6223200014     นายนิวัฒน์ รัตนสาคร  8  11  24  75  17  6
# 6   6223200019    นายชาคริต เอี่ยมสกุล  7  11  25  34   2  0
# 7   6223200021    นายนนธวัช เจริญฤทธิ์  1  18  36   0   1  5
# 8   6223200022          นายคมสัน อำนวย  7   5  60  64   3  4
# 9   6223200025         นายจรัญ รักญาติ  8  13  26  60   3  2
# 10  6223200026     นายฐิติกานต์ อิ่มใจ  7  16  21   4  19  4
# 11  6223200027  นายพรพิพัฒน์ กรรฐโรจน์  8   6  48  51  15  3
# 12  6223200030   นายภูรินทร์ กิติจนาทร  0  15  21  83  24  0
# 13  6223200031     นายกรวุฒิ อิ่มอาดูร  0  11  34  67  20  3
# 14  6223200032  นายพงษ์เพชร พุ่มลอยฟ้า  5   9  48  38  26  5
# 15  6223200033       นางสาวรณิดา นพวัง  1  19  27  68   9  7
# 16  6223220002      นายอรรถพล เนตรวงค์  8  11  31  37  29  2
# 17  6224220001       นางสาวปวีณา บุญนำ  8   6  38  96   5  4
